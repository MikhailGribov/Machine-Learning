# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("googleplaystore.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 15        3.2      55                2.7M       5,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10811     NaN       4                3.9M         100+  Free     0
# 10812     4.1      80                 13M       1,000+  Free     0
# 10813     NaN      20                2.7M      10,000+  Free     0
# 10814     4.0     785                 31M      50,000+  Free     0
# 10815     4.2    5775                4.9M     500,000+  Free     0
# 10816     NaN       2                6.8M         100+  Free     0
# 10817     4.0     885                8.0M     100,000+  Free     0
# 10818     NaN      96                1.5M      10,000+  Free     0
# 10819     3.3      52                3.6M       5,000+  Free     0
# 10820     5.0      22                8.6M       1,000+  Free     0
# 10821     NaN       6                2.5M          50+  Free     0
# 10822     NaN       0                3.1M          10+  Free     0
# 10823     NaN       1                2.9M         100+  Free     0
# 10824     NaN      67                 82M      10,000+  Free     0
# 10825     NaN       7                7.7M         100+  Free     0
# 10826     4.0   88486  Varies with device   5,000,000+  Free     0
# 10827     4.2     117                 13M       5,000+  Free     0
# 10828     3.4     291                 13M      10,000+  Free     0
# 10829     4.6     603                7.4M      10,000+  Free     0
# 10830     3.8     881                2.3M     100,000+  Free     0
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                           Genres        Last Updated  \
# 0           Everyone                     Art & Design     January 7, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 6           Everyone                     Art & Design      April 26, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 8           Everyone                     Art & Design  September 20, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 14          Everyone                     Art & Design      August 3, 2018
# 15          Everyone                     Art & Design        June 6, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 18          Everyone                     Art & Design      August 3, 2018
# 19          Everyone                     Art & Design       July 30, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 27          Everyone                     Art & Design      March 21, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# ...              ...                              ...                 ...
# 10811       Everyone                  Auto & Vehicles       July 24, 2018
# 10812       Everyone                        Education       June 13, 2018
# 10813       Everyone                         Business       July 17, 2018
# 10814           Teen                    Entertainment        June 3, 2015
# 10815       Everyone                Books & Reference       July 19, 2018
# 10816       Everyone                         Business      August 6, 2018
# 10817       Everyone                            Tools    October 30, 2015
# 10818       Everyone                          Finance        May 19, 2016
# 10819           Teen                Books & Reference      August 5, 2017
# 10820           Teen                        Education       June 27, 2018
# 10821       Everyone                    Entertainment        May 29, 2018
# 10822       Everyone                     Productivity    December 1, 2017
# 10823       Everyone          Video Players & Editors      April 22, 2018
# 10824       Everyone                          Medical       July 31, 2018
# 10825           Teen                           Social    February 2, 2018
# 10826     Mature 17+                           Social      March 23, 2018
# 10827       Everyone                        Education       June 13, 2018
# 10828       Everyone                           Comics        May 15, 2017
# 10829       Everyone                Books & Reference       June 19, 2016
# 10830       Everyone                 News & Magazines    January 20, 2014
# 10831       Everyone                Maps & Navigation       June 13, 2018
# 10832       Everyone                          Weather   February 16, 2014
# 10833       Everyone                Books & Reference      March 23, 2014
# 10834       Everyone                        Education       June 18, 2017
# 10835       Everyone                         Business  September 29, 2016
# 10836       Everyone                        Education       July 25, 2017
# 10837       Everyone                        Education        July 6, 2018
# 10838       Everyone                          Medical    January 20, 2017
# 10839     Mature 17+                Books & Reference    January 19, 2015
# 10840       Everyone                        Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# 6                     1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 8                   2.9.2          3.0 and up
# 9                     2.8        4.0.3 and up
# 10                  1.0.4          4.1 and up
# 11                 1.0.15          4.0 and up
# 12                    3.8          4.1 and up
# 13                  1.0.4          4.4 and up
# 14                  1.2.3          2.3 and up
# 15                    NaN          4.2 and up
# 16                    3.1          4.1 and up
# 17                    1.0          2.3 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 20                    4.0          4.1 and up
# 21                    1.1        4.0.3 and up
# 22                2.2.6.2        4.0.3 and up
# 23                  1.0.0          4.1 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 26                  1.0.8        4.0.3 and up
# 27                   1.03        4.0.3 and up
# 28                    6.0          2.3 and up
# 29                    1.0          2.3 and up
# ...                   ...                 ...
# 10811               1.3.6         4.4W and up
# 10812              2.0.20        4.0.3 and up
# 10813              2.1.10          4.1 and up
# 10814               1.3.1          3.0 and up
# 10815             7.0.4.6          4.2 and up
# 10816               2.1.8          4.1 and up
# 10817          1.0.612928          5.0 and up
# 10818                 2.3          2.2 and up
# 10819               0.3.4          4.1 and up
# 10820               3.8.0          4.1 and up
# 10821                 1.0        4.0.3 and up
# 10822                   1          4.4 and up
# 10823                 1.0        4.0.3 and up
# 10824               2.2.2          4.4 and up
# 10825                 1.0          4.0 and up
# 10826  Varies with device  Varies with device
# 10827              2.0.20        4.0.3 and up
# 10828               2.0.1          4.0 and up
# 10829                2.96          4.1 and up
# 10830                 1.5          1.6 and up
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
print(data)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# 11               Name Art Photo Editor - Focus n Filters       ART_AND_DESIGN
# 12                        Tattoo Name On My Photo Editor       ART_AND_DESIGN
# 13                                 Mandala Coloring Book       ART_AND_DESIGN
# 14       3D Color Pixel by Number - Sandbox Art Coloring       ART_AND_DESIGN
# 15                       Learn To Draw Kawaii Characters       ART_AND_DESIGN
# 16          Photo Designer - Write your name with shapes       ART_AND_DESIGN
# 17                              350 Diy Room Decor Ideas       ART_AND_DESIGN
# 18                         FlipaClip - Cartoon animation       ART_AND_DESIGN
# 19                                          ibis Paint X       ART_AND_DESIGN
# 20                           Logo Maker - Small Business       ART_AND_DESIGN
# 21             Boys Photo Editor - Six Pack & Men's Suit       ART_AND_DESIGN
# 22               Superheroes Wallpapers | 4K Backgrounds       ART_AND_DESIGN
# 23                                Mcqueen Coloring pages       ART_AND_DESIGN
# 24                           HD Mickey Minnie Wallpapers       ART_AND_DESIGN
# 25                            Harley Quinn wallpapers HD       ART_AND_DESIGN
# 26                         Colorfit - Drawing & Coloring       ART_AND_DESIGN
# 27                                 Animated Photo Editor       ART_AND_DESIGN
# 28                                 Pencil Sketch Drawing       ART_AND_DESIGN
# 29                       Easy Realistic Drawing Tutorial       ART_AND_DESIGN
# ...                                                  ...                  ...
# 10811                                        FR Plus 1.6    AUTO_AND_VEHICLES
# 10812                                      Fr Agnel Pune               FAMILY
# 10813                                     DICT.fr Mobile             BUSINESS
# 10814                               FR: My Secret Pets!                FAMILY
# 10815                          Golden Dictionary (FR-AR)  BOOKS_AND_REFERENCE
# 10816                                 FieldBi FR Offline             BUSINESS
# 10817                               HTC Sense Input - FR                TOOLS
# 10818                               Gold Quote - Gold.fr              FINANCE
# 10819                                          Fanfic-FR  BOOKS_AND_REFERENCE
# 10820                                    Fr. Daoud Lamei               FAMILY
# 10821                                            Poop FR               FAMILY
# 10822                                          PLMGSS FR         PRODUCTIVITY
# 10823                                       List iptv FR        VIDEO_PLAYERS
# 10824                                          Cardio-FR              MEDICAL
# 10825                                 Naruto & Boruto FR               SOCIAL
# 10826          Frim: get new friends on local chat rooms               SOCIAL
# 10827                                 Fr Agnel Ambarnath               FAMILY
# 10828                            Manga-FR - Anime Vostfr               COMICS
# 10829                     Bulgarian French Dictionary Fr  BOOKS_AND_REFERENCE
# 10830                                  News Minecraft.fr   NEWS_AND_MAGAZINES
# 10831                           payermonstationnement.fr  MAPS_AND_NAVIGATION
# 10832                                           FR Tides              WEATHER
# 10833                                        Chemin (fr)  BOOKS_AND_REFERENCE
# 10834                                      FR Calculator               FAMILY
# 10835                                           FR Forms             BUSINESS
# 10836                                   Sya9a Maroc - FR               FAMILY
# 10837                   Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                             Parkinson Exercices FR              MEDICAL
# 10839                      The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840      iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 0         4.1     159                 19M      10,000+  Free     0
# 1         3.9     967                 14M     500,000+  Free     0
# 2         4.7   87510                8.7M   5,000,000+  Free     0
# 3         4.5  215644                 25M  50,000,000+  Free     0
# 4         4.3     967                2.8M     100,000+  Free     0
# 5         4.4     167                5.6M      50,000+  Free     0
# 6         3.8     178                 19M      50,000+  Free     0
# 7         4.1   36815                 29M   1,000,000+  Free     0
# 8         4.4   13791                 33M   1,000,000+  Free     0
# 9         4.7     121                3.1M      10,000+  Free     0
# 10        4.4   13880                 28M   1,000,000+  Free     0
# 11        4.4    8788                 12M   1,000,000+  Free     0
# 12        4.2   44829                 20M  10,000,000+  Free     0
# 13        4.6    4326                 21M     100,000+  Free     0
# 14        4.4    1518                 37M     100,000+  Free     0
# 15        3.2      55                2.7M       5,000+  Free     0
# 16        4.7    3632                5.5M     500,000+  Free     0
# 17        4.5      27                 17M      10,000+  Free     0
# 18        4.3  194216                 39M   5,000,000+  Free     0
# 19        4.6  224399                 31M  10,000,000+  Free     0
# 20        4.0     450                 14M     100,000+  Free     0
# 21        4.1     654                 12M     100,000+  Free     0
# 22        4.7    7699                4.2M     500,000+  Free     0
# 23        NaN      61                7.0M     100,000+  Free     0
# 24        4.7     118                 23M      50,000+  Free     0
# 25        4.8     192                6.0M      10,000+  Free     0
# 26        4.7   20260                 25M     500,000+  Free     0
# 27        4.1     203                6.1M     100,000+  Free     0
# 28        3.9     136                4.6M      10,000+  Free     0
# 29        4.1     223                4.2M     100,000+  Free     0
# ...       ...     ...                 ...          ...   ...   ...
# 10811     NaN       4                3.9M         100+  Free     0
# 10812     4.1      80                 13M       1,000+  Free     0
# 10813     NaN      20                2.7M      10,000+  Free     0
# 10814     4.0     785                 31M      50,000+  Free     0
# 10815     4.2    5775                4.9M     500,000+  Free     0
# 10816     NaN       2                6.8M         100+  Free     0
# 10817     4.0     885                8.0M     100,000+  Free     0
# 10818     NaN      96                1.5M      10,000+  Free     0
# 10819     3.3      52                3.6M       5,000+  Free     0
# 10820     5.0      22                8.6M       1,000+  Free     0
# 10821     NaN       6                2.5M          50+  Free     0
# 10822     NaN       0                3.1M          10+  Free     0
# 10823     NaN       1                2.9M         100+  Free     0
# 10824     NaN      67                 82M      10,000+  Free     0
# 10825     NaN       7                7.7M         100+  Free     0
# 10826     4.0   88486  Varies with device   5,000,000+  Free     0
# 10827     4.2     117                 13M       5,000+  Free     0
# 10828     3.4     291                 13M      10,000+  Free     0
# 10829     4.6     603                7.4M      10,000+  Free     0
# 10830     3.8     881                2.3M     100,000+  Free     0
# 10831     NaN      38                9.8M       5,000+  Free     0
# 10832     3.8    1195                582k     100,000+  Free     0
# 10833     4.8      44                619k       1,000+  Free     0
# 10834     4.0       7                2.6M         500+  Free     0
# 10835     NaN       0                9.6M          10+  Free     0
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating                           Genres        Last Updated  \
# 0           Everyone                     Art & Design     January 7, 2018
# 1           Everyone        Art & Design;Pretend Play    January 15, 2018
# 2           Everyone                     Art & Design      August 1, 2018
# 3               Teen                     Art & Design        June 8, 2018
# 4           Everyone          Art & Design;Creativity       June 20, 2018
# 5           Everyone                     Art & Design      March 26, 2017
# 6           Everyone                     Art & Design      April 26, 2018
# 7           Everyone                     Art & Design       June 14, 2018
# 8           Everyone                     Art & Design  September 20, 2017
# 9           Everyone          Art & Design;Creativity        July 3, 2018
# 10          Everyone                     Art & Design    October 27, 2017
# 11          Everyone                     Art & Design       July 31, 2018
# 12              Teen                     Art & Design       April 2, 2018
# 13          Everyone                     Art & Design       June 26, 2018
# 14          Everyone                     Art & Design      August 3, 2018
# 15          Everyone                     Art & Design        June 6, 2018
# 16          Everyone                     Art & Design       July 31, 2018
# 17          Everyone                     Art & Design    November 7, 2017
# 18          Everyone                     Art & Design      August 3, 2018
# 19          Everyone                     Art & Design       July 30, 2018
# 20          Everyone                     Art & Design      April 20, 2018
# 21          Everyone                     Art & Design      March 20, 2018
# 22      Everyone 10+                     Art & Design       July 12, 2018
# 23          Everyone  Art & Design;Action & Adventure       March 7, 2018
# 24          Everyone                     Art & Design        July 7, 2018
# 25          Everyone                     Art & Design      April 25, 2018
# 26          Everyone          Art & Design;Creativity    October 11, 2017
# 27          Everyone                     Art & Design      March 21, 2018
# 28          Everyone                     Art & Design       July 12, 2018
# 29          Everyone                     Art & Design     August 22, 2017
# ...              ...                              ...                 ...
# 10811       Everyone                  Auto & Vehicles       July 24, 2018
# 10812       Everyone                        Education       June 13, 2018
# 10813       Everyone                         Business       July 17, 2018
# 10814           Teen                    Entertainment        June 3, 2015
# 10815       Everyone                Books & Reference       July 19, 2018
# 10816       Everyone                         Business      August 6, 2018
# 10817       Everyone                            Tools    October 30, 2015
# 10818       Everyone                          Finance        May 19, 2016
# 10819           Teen                Books & Reference      August 5, 2017
# 10820           Teen                        Education       June 27, 2018
# 10821       Everyone                    Entertainment        May 29, 2018
# 10822       Everyone                     Productivity    December 1, 2017
# 10823       Everyone          Video Players & Editors      April 22, 2018
# 10824       Everyone                          Medical       July 31, 2018
# 10825           Teen                           Social    February 2, 2018
# 10826     Mature 17+                           Social      March 23, 2018
# 10827       Everyone                        Education       June 13, 2018
# 10828       Everyone                           Comics        May 15, 2017
# 10829       Everyone                Books & Reference       June 19, 2016
# 10830       Everyone                 News & Magazines    January 20, 2014
# 10831       Everyone                Maps & Navigation       June 13, 2018
# 10832       Everyone                          Weather   February 16, 2014
# 10833       Everyone                Books & Reference      March 23, 2014
# 10834       Everyone                        Education       June 18, 2017
# 10835       Everyone                         Business  September 29, 2016
# 10836       Everyone                        Education       July 25, 2017
# 10837       Everyone                        Education        July 6, 2018
# 10838       Everyone                          Medical    January 20, 2017
# 10839     Mature 17+                Books & Reference    January 19, 2015
# 10840       Everyone                        Lifestyle       July 25, 2018
#
#               Current Ver         Android Ver
# 0                   1.0.0        4.0.3 and up
# 1                   2.0.0        4.0.3 and up
# 2                   1.2.4        4.0.3 and up
# 3      Varies with device          4.2 and up
# 4                     1.1          4.4 and up
# 5                     1.0          2.3 and up
# 6                     1.1        4.0.3 and up
# 7                6.1.61.1          4.2 and up
# 8                   2.9.2          3.0 and up
# 9                     2.8        4.0.3 and up
# 10                  1.0.4          4.1 and up
# 11                 1.0.15          4.0 and up
# 12                    3.8          4.1 and up
# 13                  1.0.4          4.4 and up
# 14                  1.2.3          2.3 and up
# 15                    NaN          4.2 and up
# 16                    3.1          4.1 and up
# 17                    1.0          2.3 and up
# 18                  2.2.5        4.0.3 and up
# 19                  5.5.4          4.1 and up
# 20                    4.0          4.1 and up
# 21                    1.1        4.0.3 and up
# 22                2.2.6.2        4.0.3 and up
# 23                  1.0.0          4.1 and up
# 24                  1.1.3          4.1 and up
# 25                    1.5          3.0 and up
# 26                  1.0.8        4.0.3 and up
# 27                   1.03        4.0.3 and up
# 28                    6.0          2.3 and up
# 29                    1.0          2.3 and up
# ...                   ...                 ...
# 10811               1.3.6         4.4W and up
# 10812              2.0.20        4.0.3 and up
# 10813              2.1.10          4.1 and up
# 10814               1.3.1          3.0 and up
# 10815             7.0.4.6          4.2 and up
# 10816               2.1.8          4.1 and up
# 10817          1.0.612928          5.0 and up
# 10818                 2.3          2.2 and up
# 10819               0.3.4          4.1 and up
# 10820               3.8.0          4.1 and up
# 10821                 1.0        4.0.3 and up
# 10822                   1          4.4 and up
# 10823                 1.0        4.0.3 and up
# 10824               2.2.2          4.4 and up
# 10825                 1.0          4.0 and up
# 10826  Varies with device  Varies with device
# 10827              2.0.20        4.0.3 and up
# 10828               2.0.1          4.0 and up
# 10829                2.96          4.1 and up
# 10830                 1.5          1.6 and up
# 10831           2.0.148.0          4.0 and up
# 10832                 6.0          2.1 and up
# 10833                 0.8          2.2 and up
# 10834               1.0.0          4.1 and up
# 10835               1.1.5          4.0 and up
# 10836                1.48          4.1 and up
# 10837                 1.0          4.1 and up
# 10838                 1.0          2.2 and up
# 10839  Varies with device  Varies with device
# 10840  Varies with device  Varies with device
#
# [10841 rows x 13 columns]

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# 1  Art & Design;Pretend Play  January 15, 2018               2.0.0
# 2               Art & Design    August 1, 2018               1.2.4
# 3               Art & Design      June 8, 2018  Varies with device
# 4    Art & Design;Creativity     June 20, 2018                 1.1
#
#     Android Ver
# 0  4.0.3 and up
# 1  4.0.3 and up
# 2  4.0.3 and up
# 3    4.2 and up
# 4    4.4 and up

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# 10836       Everyone          Education     July 25, 2017                1.48
# 10837       Everyone          Education      July 6, 2018                 1.0
# 10838       Everyone            Medical  January 20, 2017                 1.0
# 10839     Mature 17+  Books & Reference  January 19, 2015  Varies with device
# 10840       Everyone          Lifestyle     July 25, 2018  Varies with device
#
#               Android Ver
# 10836          4.1 and up
# 10837          4.1 and up
# 10838          2.2 and up
# 10839  Varies with device
# 10840  Varies with device

# %%
print(data.shape)
print(data.columns)
# Out:
# (10841, 13)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10841, step=1)

# %%
data.at[4,'App']
# Out:
# 'Pixel Draw - Number Art Coloring Book'

# %%
data['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
# 5                               Paper flowers instructions
# 6                  Smoke Effect Photo Maker - Smoke Editor
# 7                                         Infinite Painter
# 8                                     Garden Coloring Book
# 9                            Kids Paint Free - Drawing Fun
# 10                                 Text on Photo - Fonteee
# 11                 Name Art Photo Editor - Focus n Filters
# 12                          Tattoo Name On My Photo Editor
# 13                                   Mandala Coloring Book
# 14         3D Color Pixel by Number - Sandbox Art Coloring
# 15                         Learn To Draw Kawaii Characters
# 16            Photo Designer - Write your name with shapes
# 17                                350 Diy Room Decor Ideas
# 18                           FlipaClip - Cartoon animation
# 19                                            ibis Paint X
# 20                             Logo Maker - Small Business
# 21               Boys Photo Editor - Six Pack & Men's Suit
# 22                 Superheroes Wallpapers | 4K Backgrounds
# 23                                  Mcqueen Coloring pages
# 24                             HD Mickey Minnie Wallpapers
# 25                              Harley Quinn wallpapers HD
# 26                           Colorfit - Drawing & Coloring
# 27                                   Animated Photo Editor
# 28                                   Pencil Sketch Drawing
# 29                         Easy Realistic Drawing Tutorial
#                                ...
# 10811                                          FR Plus 1.6
# 10812                                        Fr Agnel Pune
# 10813                                       DICT.fr Mobile
# 10814                                 FR: My Secret Pets!
# 10815                            Golden Dictionary (FR-AR)
# 10816                                   FieldBi FR Offline
# 10817                                 HTC Sense Input - FR
# 10818                                 Gold Quote - Gold.fr
# 10819                                            Fanfic-FR
# 10820                                      Fr. Daoud Lamei
# 10821                                              Poop FR
# 10822                                            PLMGSS FR
# 10823                                         List iptv FR
# 10824                                            Cardio-FR
# 10825                                   Naruto & Boruto FR
# 10826            Frim: get new friends on local chat rooms
# 10827                                   Fr Agnel Ambarnath
# 10828                              Manga-FR - Anime Vostfr
# 10829                       Bulgarian French Dictionary Fr
# 10830                                    News Minecraft.fr
# 10831                             payermonstationnement.fr
# 10832                                             FR Tides
# 10833                                          Chemin (fr)
# 10834                                        FR Calculator
# 10835                                             FR Forms
# 10836                                     Sya9a Maroc - FR
# 10837                     Fr. Mike Schmitz Audio Teachings
# 10838                               Parkinson Exercices FR
# 10839                        The SCP Foundation DB fr nn5n
# 10840        iHoroscope - 2018 Daily Horoscope & Astrology
# Name: App, Length: 10841, dtype: object

# %%
data['App'][3]
# Out:
# 'Sketch - Draw & Paint'

# %%
data['Reviews'].dtype.name
# Out:
# 'object'

# %%
type(data['Rating'][2])
# Out:
# numpy.float64

# %%
data[['Rating','Installs']].head()
# Out:
#    Rating     Installs
# 0     4.1      10,000+
# 1     3.9     500,000+
# 2     4.7   5,000,000+
# 3     4.5  50,000,000+
# 4     4.3     100,000+

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.drop_duplicates(subset='App', inplace=True)
data = data[data['Android Ver'] != np.nan]
data = data[data['Android Ver'] != 'NaN']
data = data[data['Installs'] != 'Free']
data = data[data['Installs'] != 'Paid']
data.columns=['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
       'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Current_Ver',
       'Android_Ver']

# %% [markdown]
# Преобразую некоторые данные для дальнейших вычислений

# %%
data['Installs'] = data['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
data['Installs'] = data['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
data['Installs'] = data['Installs'].apply(lambda x: int(x))

data['Size'] = data['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)

data['Size'] = data['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
data['Size'] = data['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
data['Size'] = data['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)


data['Size'] = data['Size'].apply(lambda x: float(x))
data['Installs'] = data['Installs'].apply(lambda x: float(x))

data['Price'] = data['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
data['Price'] = data['Price'].apply(lambda x: float(x))

data['Reviews'] = data['Reviews'].apply(lambda x: int(x))

x = data['Rating'].dropna()
y = data['Size'].dropna()
z = data['Installs'][data.Installs!=0].dropna()
p = data['Reviews'][data.Reviews!=0].dropna()
t = data['Type'].dropna()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.055081  0.063067  0.040143 -0.021199
# Reviews   0.055081  1.000000  0.179321  0.625165 -0.007598
# Size      0.063067  0.179321  1.000000  0.134291 -0.022439
# Installs  0.040143  0.625165  0.134291  1.000000 -0.009405
# Price    -0.021199 -0.007598 -0.022439 -0.009405  1.000000

# %%
plt.plot(data['Size'], data['Installs'], 'o', alpha = 0.05)
plt.xlabel('Size')
plt.ylabel('Installs')
plt.title('Size and installs')
pass

# %%
data['Genres'] == 'Art & Design'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
# 5         True
# 6         True
# 7         True
# 8         True
# 9        False
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23       False
# 24        True
# 25        True
# 26       False
# 27        True
# 28        True
# 29        True
#          ...
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817    False
# 10818    False
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826    False
# 10827    False
# 10828    False
# 10829    False
# 10830    False
# 10831    False
# 10832    False
# 10833    False
# 10834    False
# 10835    False
# 10836    False
# 10837    False
# 10838    False
# 10839    False
# 10840    False
# Name: Genres, Length: 9659, dtype: bool

# %%
plt.figure(figsize = (12, 8))

plt.scatter(data[data['Content_Rating'] == 'Everyone']['Rating'],
            data[data['Content_Rating'] == 'Everyone']['Reviews'],
            alpha = 0.15,
            label = 'Everyone',
            color = 'b')

plt.scatter(data[data['Content_Rating'] == 'Mature 17+']['Rating'],
            data[data['Content_Rating'] == 'Mature 17+']['Reviews'],
            alpha = 0.05,
            label = 'Mature 17+',
            color = 'r')

plt.xlabel('Rating')
plt.ylabel('Reviews')
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                              App Category  Type Content_Rating Genres  \
# count                       9659     9659  9658           9659   9659
# unique                      9659       33     2              6    118
# top     GoPro (formerly Capture)   FAMILY  Free       Everyone  Tools
# freq                           1     1832  8902           7903    826
#
#           Last_Updated         Current_Ver Android_Ver
# count             9659                9651        9657
# unique            1377                2817          33
# top     August 3, 2018  Varies with device  4.1 and up
# freq               252                1055        2202

# %%
data.describe(include = 'all')
# Out:
#                              App Category       Rating       Reviews  \
# count                       9659     9659  8196.000000  9.659000e+03
# unique                      9659       33          NaN           NaN
# top     GoPro (formerly Capture)   FAMILY          NaN           NaN
# freq                           1     1832          NaN           NaN
# mean                         NaN      NaN     4.173243  2.165926e+05
# std                          NaN      NaN     0.536625  1.831320e+06
# min                          NaN      NaN     1.000000  0.000000e+00
# 25%                          NaN      NaN     4.000000  2.500000e+01
# 50%                          NaN      NaN     4.300000  9.670000e+02
# 75%                          NaN      NaN     4.500000  2.940100e+04
# max                          NaN      NaN     5.000000  7.815831e+07
#
#                Size      Installs  Type        Price Content_Rating Genres  \
# count   8432.000000  9.659000e+03  9658  9659.000000           9659   9659
# unique          NaN           NaN     2          NaN              6    118
# top             NaN           NaN  Free          NaN       Everyone  Tools
# freq            NaN           NaN  8902          NaN           7903    826
# mean      20.395289  7.777507e+06   NaN     1.099299            NaN    NaN
# std       21.827542  5.375828e+07   NaN    16.852152            NaN    NaN
# min        0.008500  0.000000e+00   NaN     0.000000            NaN    NaN
# 25%        4.600000  1.000000e+03   NaN     0.000000            NaN    NaN
# 50%       12.000000  1.000000e+05   NaN     0.000000            NaN    NaN
# 75%       28.000000  1.000000e+06   NaN     0.000000            NaN    NaN
# max      100.000000  1.000000e+09   NaN   400.000000            NaN    NaN
#
#           Last_Updated         Current_Ver Android_Ver
# count             9659                9651        9657
# unique            1377                2817          33
# top     August 3, 2018  Varies with device  4.1 and up
# freq               252                1055        2202
# mean               NaN                 NaN         NaN
# std                NaN                 NaN         NaN
# min                NaN                 NaN         NaN
# 25%                NaN                 NaN         NaN
# 50%                NaN                 NaN         NaN
# 75%                NaN                 NaN         NaN
# max                NaN                 NaN         NaN

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
data['Content_Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
data['Installs'].dtype.name
# Out:
# 'float64'

# %%
data['Rating'].dtype.name
# Out:
# 'float64'

# %%
data['Size'].dtype.name
# Out:
# 'float64'

# %%
data = data.drop(['App','Last_Updated','Current_Ver'], axis = 1)

# %%
data
# Out:
#                   Category  Rating  Reviews    Size    Installs  Type  Price  \
# 0           ART_AND_DESIGN     4.1      159  19.000     10000.0  Free    0.0
# 1           ART_AND_DESIGN     3.9      967  14.000    500000.0  Free    0.0
# 2           ART_AND_DESIGN     4.7    87510   8.700   5000000.0  Free    0.0
# 3           ART_AND_DESIGN     4.5   215644  25.000  50000000.0  Free    0.0
# 4           ART_AND_DESIGN     4.3      967   2.800    100000.0  Free    0.0
# 5           ART_AND_DESIGN     4.4      167   5.600     50000.0  Free    0.0
# 6           ART_AND_DESIGN     3.8      178  19.000     50000.0  Free    0.0
# 7           ART_AND_DESIGN     4.1    36815  29.000   1000000.0  Free    0.0
# 8           ART_AND_DESIGN     4.4    13791  33.000   1000000.0  Free    0.0
# 9           ART_AND_DESIGN     4.7      121   3.100     10000.0  Free    0.0
# 10          ART_AND_DESIGN     4.4    13880  28.000   1000000.0  Free    0.0
# 11          ART_AND_DESIGN     4.4     8788  12.000   1000000.0  Free    0.0
# 12          ART_AND_DESIGN     4.2    44829  20.000  10000000.0  Free    0.0
# 13          ART_AND_DESIGN     4.6     4326  21.000    100000.0  Free    0.0
# 14          ART_AND_DESIGN     4.4     1518  37.000    100000.0  Free    0.0
# 15          ART_AND_DESIGN     3.2       55   2.700      5000.0  Free    0.0
# 16          ART_AND_DESIGN     4.7     3632   5.500    500000.0  Free    0.0
# 17          ART_AND_DESIGN     4.5       27  17.000     10000.0  Free    0.0
# 18          ART_AND_DESIGN     4.3   194216  39.000   5000000.0  Free    0.0
# 19          ART_AND_DESIGN     4.6   224399  31.000  10000000.0  Free    0.0
# 20          ART_AND_DESIGN     4.0      450  14.000    100000.0  Free    0.0
# 21          ART_AND_DESIGN     4.1      654  12.000    100000.0  Free    0.0
# 22          ART_AND_DESIGN     4.7     7699   4.200    500000.0  Free    0.0
# 23          ART_AND_DESIGN     NaN       61   7.000    100000.0  Free    0.0
# 24          ART_AND_DESIGN     4.7      118  23.000     50000.0  Free    0.0
# 25          ART_AND_DESIGN     4.8      192   6.000     10000.0  Free    0.0
# 26          ART_AND_DESIGN     4.7    20260  25.000    500000.0  Free    0.0
# 27          ART_AND_DESIGN     4.1      203   6.100    100000.0  Free    0.0
# 28          ART_AND_DESIGN     3.9      136   4.600     10000.0  Free    0.0
# 29          ART_AND_DESIGN     4.1      223   4.200    100000.0  Free    0.0
# ...                    ...     ...      ...     ...         ...   ...    ...
# 10811    AUTO_AND_VEHICLES     NaN        4   3.900       100.0  Free    0.0
# 10812               FAMILY     4.1       80  13.000      1000.0  Free    0.0
# 10813             BUSINESS     NaN       20   2.700     10000.0  Free    0.0
# 10814               FAMILY     4.0      785  31.000     50000.0  Free    0.0
# 10815  BOOKS_AND_REFERENCE     4.2     5775   4.900    500000.0  Free    0.0
# 10816             BUSINESS     NaN        2   6.800       100.0  Free    0.0
# 10817                TOOLS     4.0      885   8.000    100000.0  Free    0.0
# 10818              FINANCE     NaN       96   1.500     10000.0  Free    0.0
# 10819  BOOKS_AND_REFERENCE     3.3       52   3.600      5000.0  Free    0.0
# 10820               FAMILY     5.0       22   8.600      1000.0  Free    0.0
# 10821               FAMILY     NaN        6   2.500        50.0  Free    0.0
# 10822         PRODUCTIVITY     NaN        0   3.100        10.0  Free    0.0
# 10823        VIDEO_PLAYERS     NaN        1   2.900       100.0  Free    0.0
# 10824              MEDICAL     NaN       67  82.000     10000.0  Free    0.0
# 10825               SOCIAL     NaN        7   7.700       100.0  Free    0.0
# 10826               SOCIAL     4.0    88486     NaN   5000000.0  Free    0.0
# 10827               FAMILY     4.2      117  13.000      5000.0  Free    0.0
# 10828               COMICS     3.4      291  13.000     10000.0  Free    0.0
# 10829  BOOKS_AND_REFERENCE     4.6      603   7.400     10000.0  Free    0.0
# 10830   NEWS_AND_MAGAZINES     3.8      881   2.300    100000.0  Free    0.0
# 10831  MAPS_AND_NAVIGATION     NaN       38   9.800      5000.0  Free    0.0
# 10832              WEATHER     3.8     1195   0.582    100000.0  Free    0.0
# 10833  BOOKS_AND_REFERENCE     4.8       44   0.619      1000.0  Free    0.0
# 10834               FAMILY     4.0        7   2.600       500.0  Free    0.0
# 10835             BUSINESS     NaN        0   9.600        10.0  Free    0.0
# 10836               FAMILY     4.5       38  53.000      5000.0  Free    0.0
# 10837               FAMILY     5.0        4   3.600       100.0  Free    0.0
# 10838              MEDICAL     NaN        3   9.500      1000.0  Free    0.0
# 10839  BOOKS_AND_REFERENCE     4.5      114     NaN      1000.0  Free    0.0
# 10840            LIFESTYLE     4.5   398307  19.000  10000000.0  Free    0.0
#
#       Content_Rating                           Genres         Android_Ver
# 0           Everyone                     Art & Design        4.0.3 and up
# 1           Everyone        Art & Design;Pretend Play        4.0.3 and up
# 2           Everyone                     Art & Design        4.0.3 and up
# 3               Teen                     Art & Design          4.2 and up
# 4           Everyone          Art & Design;Creativity          4.4 and up
# 5           Everyone                     Art & Design          2.3 and up
# 6           Everyone                     Art & Design        4.0.3 and up
# 7           Everyone                     Art & Design          4.2 and up
# 8           Everyone                     Art & Design          3.0 and up
# 9           Everyone          Art & Design;Creativity        4.0.3 and up
# 10          Everyone                     Art & Design          4.1 and up
# 11          Everyone                     Art & Design          4.0 and up
# 12              Teen                     Art & Design          4.1 and up
# 13          Everyone                     Art & Design          4.4 and up
# 14          Everyone                     Art & Design          2.3 and up
# 15          Everyone                     Art & Design          4.2 and up
# 16          Everyone                     Art & Design          4.1 and up
# 17          Everyone                     Art & Design          2.3 and up
# 18          Everyone                     Art & Design        4.0.3 and up
# 19          Everyone                     Art & Design          4.1 and up
# 20          Everyone                     Art & Design          4.1 and up
# 21          Everyone                     Art & Design        4.0.3 and up
# 22      Everyone 10+                     Art & Design        4.0.3 and up
# 23          Everyone  Art & Design;Action & Adventure          4.1 and up
# 24          Everyone                     Art & Design          4.1 and up
# 25          Everyone                     Art & Design          3.0 and up
# 26          Everyone          Art & Design;Creativity        4.0.3 and up
# 27          Everyone                     Art & Design        4.0.3 and up
# 28          Everyone                     Art & Design          2.3 and up
# 29          Everyone                     Art & Design          2.3 and up
# ...              ...                              ...                 ...
# 10811       Everyone                  Auto & Vehicles         4.4W and up
# 10812       Everyone                        Education        4.0.3 and up
# 10813       Everyone                         Business          4.1 and up
# 10814           Teen                    Entertainment          3.0 and up
# 10815       Everyone                Books & Reference          4.2 and up
# 10816       Everyone                         Business          4.1 and up
# 10817       Everyone                            Tools          5.0 and up
# 10818       Everyone                          Finance          2.2 and up
# 10819           Teen                Books & Reference          4.1 and up
# 10820           Teen                        Education          4.1 and up
# 10821       Everyone                    Entertainment        4.0.3 and up
# 10822       Everyone                     Productivity          4.4 and up
# 10823       Everyone          Video Players & Editors        4.0.3 and up
# 10824       Everyone                          Medical          4.4 and up
# 10825           Teen                           Social          4.0 and up
# 10826     Mature 17+                           Social  Varies with device
# 10827       Everyone                        Education        4.0.3 and up
# 10828       Everyone                           Comics          4.0 and up
# 10829       Everyone                Books & Reference          4.1 and up
# 10830       Everyone                 News & Magazines          1.6 and up
# 10831       Everyone                Maps & Navigation          4.0 and up
# 10832       Everyone                          Weather          2.1 and up
# 10833       Everyone                Books & Reference          2.2 and up
# 10834       Everyone                        Education          4.1 and up
# 10835       Everyone                         Business          4.0 and up
# 10836       Everyone                        Education          4.1 and up
# 10837       Everyone                        Education          4.1 and up
# 10838       Everyone                          Medical          2.2 and up
# 10839     Mature 17+                Books & Reference  Varies with device
# 10840       Everyone                        Lifestyle  Varies with device
#
# [9659 rows x 10 columns]

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['Category', 'Type', 'Content_Rating', 'Genres', 'Android_Ver']
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price']

# %%
data.median(axis = 0)
# Out:
# Rating           4.3
# Reviews        967.0
# Size            12.0
# Installs    100000.0
# Price            0.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# Rating      9659
# Reviews     9659
# Size        9659
# Installs    9659
# Price       9659
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# Category          9659
# Type              9658
# Content_Rating    9659
# Genres            9659
# Android_Ver       9657
# dtype: int64

# %%
data['Content_Rating'].describe()
# Out:
# count         9659
# unique           6
# top       Everyone
# freq          7903
# Name: Content_Rating, dtype: object

# %%
data['Content_Rating'].describe().top
# Out:
# 'Everyone'

# %%
data['Content_Rating'] = data['Content_Rating'].fillna('Everyone')

# %%
data.describe(include = [object])
# Out:
#        Category  Type Content_Rating Genres Android_Ver
# count      9659  9658           9659   9659        9657
# unique       33     2              6    118          33
# top      FAMILY  Free       Everyone  Tools  4.1 and up
# freq       1832  8902           7903    826        2202

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#        Category  Type Content_Rating Genres Android_Ver
# count      9659  9659           9659   9659        9659
# unique       33     2              6    118          33
# top      FAMILY  Free       Everyone  Tools  4.1 and up
# freq       1832  8903           7903    826        2204

# %%
#Ранее я удалил столбцы App, last_updated  и current_ver из-за большего числа уникальных элементов

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['Type'] ['Category', 'Content_Rating', 'Genres', 'Android_Ver']

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
data.at[data['Type'] == 'Free', 'Type'] = 0
data.at[data['Type'] == 'Paid', 'Type'] = 1
data['Type'].describe()
# Out:
# count    9659.000000
# mean        0.078269
# std         0.268608
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Type, dtype: float64

# %%
data['Content_Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
#data.drop(['App','Last_Updated','Current_Ver'], axis = 1)

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['Category_ART_AND_DESIGN', 'Category_AUTO_AND_VEHICLES',
#        'Category_BEAUTY', 'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS',
#        'Category_COMICS', 'Category_COMMUNICATION', 'Category_DATING',
#        'Category_EDUCATION', 'Category_ENTERTAINMENT',
#        ...
#        'Android_Ver_5.0 - 7.1.1', 'Android_Ver_5.0 - 8.0',
#        'Android_Ver_5.0 and up', 'Android_Ver_5.1 and up',
#        'Android_Ver_6.0 and up', 'Android_Ver_7.0 - 7.1.1',
#        'Android_Ver_7.0 and up', 'Android_Ver_7.1 and up',
#        'Android_Ver_8.0 and up', 'Android_Ver_Varies with device'],
#       dtype='object', length=190)

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  9659.000000  9.659000e+03  9659.000000  9.659000e+03  9659.000000
# mean      4.192442  2.165926e+05    19.328821  7.777507e+06     1.099299
# std       0.496397  1.831320e+06    20.584676  5.375828e+07    16.852152
# min       1.000000  0.000000e+00     0.008500  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.300000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02    12.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04    25.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price
# count  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03
# mean  -1.290969e-13 -1.812561e-16  5.170289e-15 -1.300256e-15 -2.643374e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.431227e+00 -1.182713e-01 -9.385778e-01 -1.446755e-01 -6.523197e-02
# 25%   -3.876781e-01 -1.182577e-01 -6.815177e-01 -1.446569e-01 -6.523197e-02
# 50%    2.166768e-01 -1.177433e-01 -3.560328e-01 -1.428153e-01 -6.523197e-02
# 75%    6.195800e-01 -1.022168e-01  2.755049e-01 -1.260737e-01 -6.523197e-02
# max    1.626838e+00  4.256041e+01  3.918992e+00  1.845711e+01  2.367061e+01

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (9659, 196)

# %%
data.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price  \
# count  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03
# mean  -1.290969e-13 -1.812561e-16  5.170289e-15 -1.300256e-15 -2.643374e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.431227e+00 -1.182713e-01 -9.385778e-01 -1.446755e-01 -6.523197e-02
# 25%   -3.876781e-01 -1.182577e-01 -6.815177e-01 -1.446569e-01 -6.523197e-02
# 50%    2.166768e-01 -1.177433e-01 -3.560328e-01 -1.428153e-01 -6.523197e-02
# 75%    6.195800e-01 -1.022168e-01  2.755049e-01 -1.260737e-01 -6.523197e-02
# max    1.626838e+00  4.256041e+01  3.918992e+00  1.845711e+01  2.367061e+01
#
#        Category_ART_AND_DESIGN  Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# count              9659.000000                   9659.0000      9659.000000
# mean                  0.006626                      0.0088         0.005487
# std                   0.081134                      0.0934         0.073875
# min                   0.000000                      0.0000         0.000000
# 25%                   0.000000                      0.0000         0.000000
# 50%                   0.000000                      0.0000         0.000000
# 75%                   0.000000                      0.0000         0.000000
# max                   1.000000                      1.0000         1.000000
#
#        Category_BOOKS_AND_REFERENCE  Category_BUSINESS  ...  \
# count                   9659.000000        9659.000000  ...
# mean                       0.022984           0.043483  ...
# std                        0.149859           0.203952  ...
# min                        0.000000           0.000000  ...
# 25%                        0.000000           0.000000  ...
# 50%                        0.000000           0.000000  ...
# 75%                        0.000000           0.000000  ...
# max                        1.000000           1.000000  ...
#
#        Android_Ver_5.0 - 8.0  Android_Ver_5.0 and up  Android_Ver_5.1 and up  \
# count            9659.000000             9659.000000             9659.000000
# mean                0.000207                0.053008                0.002278
# std                 0.014389                0.224060                0.047673
# min                 0.000000                0.000000                0.000000
# 25%                 0.000000                0.000000                0.000000
# 50%                 0.000000                0.000000                0.000000
# 75%                 0.000000                0.000000                0.000000
# max                 1.000000                1.000000                1.000000
#
#        Android_Ver_6.0 and up  Android_Ver_7.0 - 7.1.1  \
# count             9659.000000              9659.000000
# mean                 0.005591                 0.000104
# std                  0.074565                 0.010175
# min                  0.000000                 0.000000
# 25%                  0.000000                 0.000000
# 50%                  0.000000                 0.000000
# 75%                  0.000000                 0.000000
# max                  1.000000                 1.000000
#
#        Android_Ver_7.0 and up  Android_Ver_7.1 and up  Android_Ver_8.0 and up  \
# count             9659.000000             9659.000000             9659.000000
# mean                 0.004348                0.000311                0.000621
# std                  0.065801                0.017622                0.024917
# min                  0.000000                0.000000                0.000000
# 25%                  0.000000                0.000000                0.000000
# 50%                  0.000000                0.000000                0.000000
# 75%                  0.000000                0.000000                0.000000
# max                  1.000000                1.000000                1.000000
#
#        Android_Ver_Varies with device         Type
# count                     9659.000000  9659.000000
# mean                         0.102495     0.078269
# std                          0.303314     0.268608
# min                          0.000000     0.000000
# 25%                          0.000000     0.000000
# 50%                          0.000000     0.000000
# 75%                          0.000000     0.000000
# max                          1.000000     1.000000
#
# [8 rows x 196 columns]

# %%
X = data.drop(('Type'), axis = 1) 
y = data['Type']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['Rating', 'Reviews', 'Size', 'Installs', 'Price',
#        'Category_ART_AND_DESIGN', 'Category_AUTO_AND_VEHICLES',
#        'Category_BEAUTY', 'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS',
#        ...
#        'Android_Ver_5.0 - 7.1.1', 'Android_Ver_5.0 - 8.0',
#        'Android_Ver_5.0 and up', 'Android_Ver_5.1 and up',
#        'Android_Ver_6.0 and up', 'Android_Ver_7.0 - 7.1.1',
#        'Android_Ver_7.0 and up', 'Android_Ver_7.1 and up',
#        'Android_Ver_8.0 and up', 'Android_Ver_Varies with device'],
#       dtype='object', length=195)

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (9659, 195)
# (9659,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 6761 2898

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0696642508504659 0.07142857142857142

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[2676    1]
#  [ 206   15]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.06892471527880495 5

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.05886703150421535 0.06694271911663216

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.0724744860227777 0.07039337474120083

# %%
from sklearn.model_selection import learning_curve,GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.0 1000.0

# %%
svc = SVC(C = best_C).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.05886703150421535 0.06694271911663216

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# 0.9999999999999999

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'Price' (0.733780)
#  2. feature 'Reviews' (0.043732)
#  3. feature 'Installs' (0.041732)
#  4. feature ' Size' (0.033056)
#  5. feature 'Rating' (0.021661)
#  6. feature 'Android_Ver_1.6 and up' (0.004810)
#  7. feature 'Genres_Education;Pretend Play' (0.004548)
#  8. feature 'Genres_Personalization' (0.004381)
#  9. feature 'Category_PERSONALIZATION' (0.004324)
# 10. feature 'Android_Ver_Varies with device' (0.004050)
# 11. feature 'Genres_Medical' (0.003416)
# 12. feature 'Category_MEDICAL' (0.003293)
# 13. feature 'Genres_Board;Brain Games' (0.003205)
# 14. feature 'Android_Ver_4.1 and up' (0.003200)
# 15. feature 'Android_Ver_4.0 and up' (0.003139)
# 16. feature 'Android_Ver_2.3 and up' (0.002959)
# 17. feature 'Android_Ver_7.0 and up' (0.002905)
# 18. feature 'Content_Rating_Everyone' (0.002867)
# 19. feature 'Genres_Role Playing' (0.002724)
# 20. feature 'Android_Ver_4.0.3 and up' (0.002693)
# 21. feature 'Android_Ver_2.1 and up' (0.002410)
# 22. feature 'Android_Ver_2.2 and up' (0.002255)
# 23. feature 'Android_Ver_4.4 and up' (0.002167)
# 24. feature 'Content_Rating_Teen' (0.002163)
# 25. feature 'Genres_Educational;Pretend Play' (0.002154)
# 26. feature 'Genres_Puzzle' (0.001986)
# 27. feature 'Category_FAMILY' (0.001926)
# 28. feature 'Android_Ver_2.3.3 and up' (0.001880)
# 29. feature 'Category_GAME' (0.001603)
# 30. feature 'Android_Ver_5.0 and up' (0.001565)
# 31. feature 'Genres_Adventure' (0.001556)
# 32. feature 'Android_Ver_3.0 and up' (0.001446)
# 33. feature 'Genres_Arcade' (0.001398)
# 34. feature 'Android_Ver_4.2 and up' (0.001365)
# 35. feature 'Android_Ver_3.2 and up' (0.001324)
# 36. feature 'Content_Rating_Everyone 10+' (0.001209)
# 37. feature 'Genres_Simulation;Education' (0.001207)
# 38. feature 'Genres_Entertainment' (0.001138)
# 39. feature 'Android_Ver_1.5 and up' (0.001136)
# 40. feature 'Genres_Education' (0.001112)
# 41. feature 'Category_BOOKS_AND_REFERENCE' (0.001085)
# 42. feature 'Android_Ver_2.0.1 and up' (0.001068)
# 43. feature 'Android_Ver_4.3 and up' (0.001040)
# 44. feature 'Content_Rating_Mature 17+' (0.001028)
# 45. feature 'Category_TOOLS' (0.001027)
# 46. feature 'Genres_Strategy' (0.001022)
# 47. feature 'Genres_Sports;Action & Adventure' (0.001018)
# 48. feature 'Genres_Educational;Creativity' (0.001017)
# 49. feature 'Genres_Books & Reference' (0.001008)
# 50. feature 'Genres_Casual;Pretend Play' (0.000972)
# 51. feature 'Genres_Tools' (0.000946)
# 52. feature 'Genres_Action' (0.000885)
# 53. feature 'Android_Ver_2.0 and up' (0.000814)
# 54. feature 'Category_BUSINESS' (0.000771)
# 55. feature 'Category_COMMUNICATION' (0.000739)
# 56. feature 'Genres_Sports' (0.000705)
# 57. feature 'Genres_Communication' (0.000675)
# 58. feature 'Genres_Productivity' (0.000671)
# 59. feature 'Category_PHOTOGRAPHY' (0.000658)
# 60. feature 'Genres_Photography' (0.000658)
# 61. feature 'Genres_Business' (0.000656)
# 62. feature 'Genres_Weather' (0.000645)
# 63. feature 'Android_Ver_6.0 and up' (0.000632)
# 64. feature 'Category_PRODUCTIVITY' (0.000614)
# 65. feature 'Category_SPORTS' (0.000612)
# 66. feature 'Genres_Simulation' (0.000607)
# 67. feature 'Genres_Education;Education' (0.000585)
# 68. feature 'Genres_Action;Action & Adventure' (0.000580)
# 69. feature 'Category_LIFESTYLE' (0.000522)
# 70. feature 'Genres_Finance' (0.000520)
# 71. feature 'Category_WEATHER' (0.000513)
# 72. feature 'Category_FINANCE' (0.000511)
# 73. feature 'Genres_Adventure;Action & Adventure' (0.000494)
# 74. feature 'Genres_Adventure;Brain Games' (0.000493)
# 75. feature 'Genres_Lifestyle' (0.000456)
# 76. feature 'Genres_Board' (0.000446)
# 77. feature 'Genres_Card' (0.000444)
# 78. feature 'Genres_Books & Reference;Creativity' (0.000443)
# 79. feature 'Genres_Casual' (0.000429)
# 80. feature 'Genres_Education;Brain Games' (0.000413)
# 81. feature 'Genres_Health & Fitness' (0.000412)
# 82. feature 'Genres_Board;Action & Adventure' (0.000409)
# 83. feature 'Category_HEALTH_AND_FITNESS' (0.000405)
# 84. feature 'Genres_Books & Reference;Education' (0.000394)
# 85. feature 'Genres_Strategy;Action & Adventure' (0.000391)
# 86. feature 'Genres_Puzzle;Brain Games' (0.000387)
# 87. feature 'Genres_Racing' (0.000379)
# 88. feature 'Genres_Travel & Local' (0.000377)
# 89. feature 'Category_EDUCATION' (0.000374)
# 90. feature 'Genres_Board;Pretend Play' (0.000367)
# 91. feature 'Genres_Casual;Education' (0.000364)
# 92. feature 'Genres_Educational' (0.000342)
# 93. feature 'Genres_Music;Music & Video' (0.000334)
# 94. feature 'Category_TRAVEL_AND_LOCAL' (0.000317)
# 95. feature 'Category_LIBRARIES_AND_DEMO' (0.000304)
# 96. feature 'Category_SOCIAL' (0.000298)
# 97. feature 'Android_Ver_4.4W and up' (0.000288)
# 98. feature 'Genres_Social' (0.000285)
# 99. feature 'Genres_Libraries & Demo' (0.000273)
# 100. feature 'Genres_Role Playing;Action & Adventure' (0.000273)
# 101. feature 'Genres_Education;Creativity' (0.000254)
# 102. feature 'Android_Ver_8.0 and up' (0.000251)
# 103. feature 'Genres_News & Magazines' (0.000250)
# 104. feature 'Category_NEWS_AND_MAGAZINES' (0.000245)
# 105. feature 'Genres_Casual;Action & Adventure' (0.000236)
# 106. feature 'Genres_Educational;Education' (0.000232)
# 107. feature 'Category_DATING' (0.000217)
# 108. feature 'Category_ENTERTAINMENT' (0.000207)
# 109. feature 'Android_Ver_5.1 and up' (0.000205)
# 110. feature 'Category_MAPS_AND_NAVIGATION' (0.000193)
# 111. feature 'Category_VIDEO_PLAYERS' (0.000192)
# 112. feature 'Genres_Dating' (0.000176)
# 113. feature 'Genres_Maps & Navigation' (0.000174)
# 114. feature 'Genres_Video Players & Editors' (0.000174)
# 115. feature 'Genres_Parenting' (0.000160)
# 116. feature 'Category_PARENTING' (0.000145)
# 117. feature 'Genres_Trivia' (0.000135)
# 118. feature 'Genres_Food & Drink' (0.000132)
# 119. feature 'Category_FOOD_AND_DRINK' (0.000129)
# 120. feature 'Android_Ver_3.1 and up' (0.000129)
# 121. feature 'Genres_Auto & Vehicles' (0.000120)
# 122. feature 'Category_SHOPPING' (0.000115)
# 123. feature 'Genres_Shopping' (0.000106)
# 124. feature 'Genres_Art & Design' (0.000099)
# 125. feature 'Category_AUTO_AND_VEHICLES' (0.000093)
# 126. feature 'Category_ART_AND_DESIGN' (0.000084)
# 127. feature 'Genres_Events' (0.000083)
# 128. feature 'Category_EVENTS' (0.000079)
# 129. feature 'Genres_Casino' (0.000049)
# 130. feature 'Genres_Music' (0.000045)
# 131. feature 'Category_COMICS' (0.000043)
# 132. feature 'Android_Ver_5.0 - 6.0' (0.000043)
# 133. feature 'Genres_Beauty' (0.000034)
# 134. feature 'Genres_Comics' (0.000034)
# 135. feature 'Genres_Arcade;Action & Adventure' (0.000033)
# 136. feature 'Category_BEAUTY' (0.000031)
# 137. feature 'Genres_Word' (0.000028)
# 138. feature 'Category_HOUSE_AND_HOME' (0.000028)
# 139. feature 'Genres_Entertainment;Music & Video' (0.000027)
# 140. feature 'Genres_Simulation;Pretend Play' (0.000025)
# 141. feature 'Genres_House & Home' (0.000024)
# 142. feature 'Genres_Education;Music & Video' (0.000012)
# 143. feature 'Android_Ver_2.2 - 7.1.1' (0.000012)
# 144. feature 'Genres_Casual;Brain Games' (0.000011)
# 145. feature 'Android_Ver_1.0 and up' (0.000006)
# 146. feature 'Genres_Art & Design;Creativity' (0.000005)
# 147. feature 'Genres_Parenting;Music & Video' (0.000004)
# 148. feature 'Genres_Health & Fitness;Education' (0.000003)
# 149. feature 'Genres_Casual;Creativity' (0.000003)
# 150. feature 'Genres_Puzzle;Education' (0.000003)
# 151. feature 'Genres_Parenting;Education' (0.000003)
# 152. feature 'Genres_Racing;Action & Adventure' (0.000002)
# 153. feature 'Genres_Travel & Local;Action & Adventure' (0.000002)
# 154. feature 'Genres_Simulation;Action & Adventure' (0.000002)
# 155. feature 'Genres_Entertainment;Brain Games' (0.000001)
# 156. feature 'Genres_Music & Audio;Music & Video' (0.000001)
# 157. feature 'Genres_Card;Action & Adventure' (0.000001)
# 158. feature 'Android_Ver_5.0 - 8.0' (0.000001)
# 159. feature 'Content_Rating_Unrated' (0.000001)
# 160. feature 'Genres_Puzzle;Action & Adventure' (0.000000)
# 161. feature 'Genres_Educational;Brain Games' (0.000000)
# 162. feature 'Genres_Health & Fitness;Action & Adventure' (0.000000)
# 163. feature 'Content_Rating_Adults only 18+' (0.000000)
# 164. feature 'Genres_Video Players & Editors;Music & Video' (0.000000)
# 165. feature 'Android_Ver_5.0 - 7.1.1' (0.000000)
# 166. feature 'Genres_Role Playing;Pretend Play' (0.000000)
# 167. feature 'Genres_Parenting;Brain Games' (0.000000)
# 168. feature 'Genres_Casual;Music & Video' (0.000000)
# 169. feature 'Genres_Tools;Education' (0.000000)
# 170. feature 'Android_Ver_7.0 - 7.1.1' (0.000000)
# 171. feature 'Android_Ver_4.0.3 - 7.1.1' (0.000000)
# 172. feature 'Genres_Entertainment;Action & Adventure' (0.000000)
# 173. feature 'Genres_Educational;Action & Adventure' (0.000000)
# 174. feature 'Genres_Adventure;Education' (0.000000)
# 175. feature 'Genres_Education;Action & Adventure' (0.000000)
# 176. feature 'Android_Ver_7.1 and up' (0.000000)
# 177. feature 'Genres_Role Playing;Brain Games' (0.000000)
# 178. feature 'Genres_Lifestyle;Education' (0.000000)
# 179. feature 'Android_Ver_4.1 - 7.1.1' (0.000000)
# 180. feature 'Genres_Entertainment;Education' (0.000000)
# 181. feature 'Genres_Puzzle;Creativity' (0.000000)
# 182. feature 'Genres_Entertainment;Creativity' (0.000000)
# 183. feature 'Genres_Art & Design;Action & Adventure' (0.000000)
# 184. feature 'Genres_Racing;Pretend Play' (0.000000)
# 185. feature 'Genres_Entertainment;Pretend Play' (0.000000)
# 186. feature 'Genres_Art & Design;Pretend Play' (0.000000)
# 187. feature 'Genres_Role Playing;Education' (0.000000)
# 188. feature 'Genres_Comics;Creativity' (0.000000)
# 189. feature 'Genres_Video Players & Editors;Creativity' (0.000000)
# 190. feature 'Genres_Trivia;Education' (0.000000)
# 191. feature 'Genres_Strategy;Education' (0.000000)
# 192. feature 'Genres_Strategy;Creativity' (0.000000)
# 193. feature 'Genres_Communication;Creativity' (0.000000)
# 194. feature 'Genres_Lifestyle;Pretend Play' (0.000000)
# 195. feature 'Genres_Arcade;Pretend Play' (0.000000)

# %%
feature_names[[1,0,1]]
# Out:
# Index(['Reviews', 'Rating', 'Reviews'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.03140096618357488

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0

# %%
# После этапа векторизации размер моей базы составил (9659, 14049). Я пытался удалить столбцы с наибольшим количеством 
# уникальных элементов, но они всё-равно остаются в базе. Думаю проблема этом. Все данные приведены к нужному типу, 
# ошибка возникает во время обучения.
# upd: столбцы удалились - я не обновлял базу данных. Y сделал бинарным (был float с ошибкой). После kNN и SVC долго считает.
