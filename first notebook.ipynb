# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
data = pd.read_csv("googleplaystore.csv")

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
print(data)
# Out:
#                                                      App             Category  \
# 0         Photo Editor & Candy Camera & Grid & ScrapBook       ART_AND_DESIGN
# 1                                    Coloring book moana       ART_AND_DESIGN
# 2      U Launcher Lite – FREE Live Cool Themes, Hide ...       ART_AND_DESIGN
# 3                                  Sketch - Draw & Paint       ART_AND_DESIGN
# 4                  Pixel Draw - Number Art Coloring Book       ART_AND_DESIGN
# 5                             Paper flowers instructions       ART_AND_DESIGN
# 6                Smoke Effect Photo Maker - Smoke Editor       ART_AND_DESIGN
# 7                                       Infinite Painter       ART_AND_DESIGN
# 8                                   Garden Coloring Book       ART_AND_DESIGN
# 9                          Kids Paint Free - Drawing Fun       ART_AND_DESIGN
# 10                               Text on Photo - Fonteee       ART_AND_DESIGN
# ...

# %%
data.head()
# Out:
#                                                  App        Category  Rating  \
# 0     Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN     4.1
# 1                                Coloring book moana  ART_AND_DESIGN     3.9
# 2  U Launcher Lite – FREE Live Cool Themes, Hide ...  ART_AND_DESIGN     4.7
# 3                              Sketch - Draw & Paint  ART_AND_DESIGN     4.5
# 4              Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN     4.3
#
#   Reviews  Size     Installs  Type Price Content Rating  \
# 0     159   19M      10,000+  Free     0       Everyone
# 1     967   14M     500,000+  Free     0       Everyone
# 2   87510  8.7M   5,000,000+  Free     0       Everyone
# 3  215644   25M  50,000,000+  Free     0           Teen
# 4     967  2.8M     100,000+  Free     0       Everyone
#
#                       Genres      Last Updated         Current Ver  \
# 0               Art & Design   January 7, 2018               1.0.0
# ...

# %%
data.tail()
# Out:
#                                                  App             Category  \
# 10836                               Sya9a Maroc - FR               FAMILY
# 10837               Fr. Mike Schmitz Audio Teachings               FAMILY
# 10838                         Parkinson Exercices FR              MEDICAL
# 10839                  The SCP Foundation DB fr nn5n  BOOKS_AND_REFERENCE
# 10840  iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE
#
#        Rating Reviews                Size     Installs  Type Price  \
# 10836     4.5      38                 53M       5,000+  Free     0
# 10837     5.0       4                3.6M         100+  Free     0
# 10838     NaN       3                9.5M       1,000+  Free     0
# 10839     4.5     114  Varies with device       1,000+  Free     0
# 10840     4.5  398307                 19M  10,000,000+  Free     0
#
#       Content Rating             Genres      Last Updated         Current Ver  \
# ...

# %%
print(data.shape)
print(data.columns)
# Out:
# (10841, 13)
# Index(['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
#        'Price', 'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=10841, step=1)

# %%
data.at[4,'App']
# Out:
# 'Pixel Draw - Number Art Coloring Book'

# %%
data['App']
# Out:
# 0           Photo Editor & Candy Camera & Grid & ScrapBook
# 1                                      Coloring book moana
# 2        U Launcher Lite – FREE Live Cool Themes, Hide ...
# 3                                    Sketch - Draw & Paint
# 4                    Pixel Draw - Number Art Coloring Book
# 5                               Paper flowers instructions
# 6                  Smoke Effect Photo Maker - Smoke Editor
# 7                                         Infinite Painter
# 8                                     Garden Coloring Book
# 9                            Kids Paint Free - Drawing Fun
# 10                                 Text on Photo - Fonteee
# 11                 Name Art Photo Editor - Focus n Filters
# 12                          Tattoo Name On My Photo Editor
# 13                                   Mandala Coloring Book
# 14         3D Color Pixel by Number - Sandbox Art Coloring
# 15                         Learn To Draw Kawaii Characters
# ...

# %%
data['App'][3]
# Out:
# 'Sketch - Draw & Paint'

# %%
data['Reviews'].dtype.name
# Out:
# 'object'

# %%
type(data['Rating'][2])
# Out:
# numpy.float64

# %%
data[['Rating','Installs']].head()
# Out:
#    Rating     Installs
# 0     4.1      10,000+
# 1     3.9     500,000+
# 2     4.7   5,000,000+
# 3     4.5  50,000,000+
# 4     4.3     100,000+

# %%
data.describe()
# Out:
#             Rating
# count  9367.000000
# mean      4.193338
# std       0.537431
# min       1.000000
# 25%       4.000000
# 50%       4.300000
# 75%       4.500000
# max      19.000000

# %%
data.drop_duplicates(subset='App', inplace=True)
data = data[data['Android Ver'] != np.nan]
data = data[data['Android Ver'] != 'NaN']
data = data[data['Installs'] != 'Free']
data = data[data['Installs'] != 'Paid']
data.columns=['App', 'Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type',
       'Price', 'Content_Rating', 'Genres', 'Last_Updated', 'Current_Ver',
       'Android_Ver']

# %% [markdown]
# Преобразую некоторые данные для дальнейших вычислений

# %%
data['Installs'] = data['Installs'].apply(lambda x: x.replace('+', '') if '+' in str(x) else x)
data['Installs'] = data['Installs'].apply(lambda x: x.replace(',', '') if ',' in str(x) else x)
data['Installs'] = data['Installs'].apply(lambda x: int(x))

data['Size'] = data['Size'].apply(lambda x: str(x).replace('Varies with device', 'NaN') if 'Varies with device' in str(x) else x)

data['Size'] = data['Size'].apply(lambda x: str(x).replace('M', '') if 'M' in str(x) else x)
data['Size'] = data['Size'].apply(lambda x: str(x).replace(',', '') if 'M' in str(x) else x)
data['Size'] = data['Size'].apply(lambda x: float(str(x).replace('k', '')) / 1000 if 'k' in str(x) else x)


data['Size'] = data['Size'].apply(lambda x: float(x))
data['Installs'] = data['Installs'].apply(lambda x: float(x))

data['Price'] = data['Price'].apply(lambda x: str(x).replace('$', '') if '$' in str(x) else str(x))
data['Price'] = data['Price'].apply(lambda x: float(x))

data['Reviews'] = data['Reviews'].apply(lambda x: int(x))

x = data['Rating'].dropna()
y = data['Size'].dropna()
z = data['Installs'][data.Installs!=0].dropna()
p = data['Reviews'][data.Reviews!=0].dropna()
t = data['Type'].dropna()

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data, alpha = .01, figsize = (10, 10))
pass

# %%
data.corr()
# Out:
#             Rating   Reviews      Size  Installs     Price
# Rating    1.000000  0.055081  0.063067  0.040143 -0.021199
# Reviews   0.055081  1.000000  0.179321  0.625165 -0.007598
# Size      0.063067  0.179321  1.000000  0.134291 -0.022439
# Installs  0.040143  0.625165  0.134291  1.000000 -0.009405
# Price    -0.021199 -0.007598 -0.022439 -0.009405  1.000000

# %%
plt.plot(data['Size'], data['Installs'], 'o', alpha = 0.05)
plt.xlabel('Size')
plt.ylabel('Installs')
plt.title('Size and installs')
pass

# %%
data['Genres'] == 'Art & Design'
# Out:
# 0         True
# 1        False
# 2         True
# 3         True
# 4        False
# 5         True
# 6         True
# 7         True
# 8         True
# 9        False
# 10        True
# 11        True
# 12        True
# 13        True
# 14        True
# 15        True
# 16        True
# 17        True
# 18        True
# 19        True
# 20        True
# 21        True
# 22        True
# 23       False
# 24        True
# 25        True
# 26       False
# 27        True
# 28        True
# 29        True
#          ...
# 10811    False
# 10812    False
# 10813    False
# 10814    False
# 10815    False
# 10816    False
# 10817    False
# 10818    False
# 10819    False
# 10820    False
# 10821    False
# 10822    False
# 10823    False
# 10824    False
# 10825    False
# 10826    False
# 10827    False
# 10828    False
# 10829    False
# 10830    False
# 10831    False
# 10832    False
# 10833    False
# 10834    False
# 10835    False
# 10836    False
# 10837    False
# ...

# %%
plt.figure(figsize = (12, 8))

plt.scatter(data[data['Content_Rating'] == 'Everyone']['Rating'],
            data[data['Content_Rating'] == 'Everyone']['Reviews'],
            alpha = 0.15,
            label = 'Everyone',
            color = 'b')

plt.scatter(data[data['Content_Rating'] == 'Mature 17+']['Rating'],
            data[data['Content_Rating'] == 'Mature 17+']['Reviews'],
            alpha = 0.05,
            label = 'Mature 17+',
            color = 'r')

plt.xlabel('Rating')
plt.ylabel('Reviews')
plt.legend()
plt.grid()

# %%
data.describe(include = ['object'])
# Out:
#                    App Category  Type Content_Rating Genres    Last_Updated  \
# count             9659     9659  9658           9659   9659            9659
# unique            9659       33     2              6    118            1377
# top     Farsi Keyboard   FAMILY  Free       Everyone  Tools  August 3, 2018
# freq                 1     1832  8902           7903    826             252
#
#                Current_Ver Android_Ver
# count                 9651        9657
# unique                2817          33
# top     Varies with device  4.1 and up
# freq                  1055        2202

# %%
data.describe(include = 'all')
# Out:
#                    App Category       Rating       Reviews         Size  \
# count             9659     9659  8196.000000  9.659000e+03  8432.000000
# unique            9659       33          NaN           NaN          NaN
# top     Farsi Keyboard   FAMILY          NaN           NaN          NaN
# freq                 1     1832          NaN           NaN          NaN
# mean               NaN      NaN     4.173243  2.165926e+05    20.395289
# std                NaN      NaN     0.536625  1.831320e+06    21.827542
# min                NaN      NaN     1.000000  0.000000e+00     0.008500
# 25%                NaN      NaN     4.000000  2.500000e+01     4.600000
# 50%                NaN      NaN     4.300000  9.670000e+02    12.000000
# 75%                NaN      NaN     4.500000  2.940100e+04    28.000000
# max                NaN      NaN     5.000000  7.815831e+07   100.000000
#
#             Installs  Type        Price Content_Rating Genres    Last_Updated  \
# ...

# %%
data['Category'].unique()
# Out:
# array(['ART_AND_DESIGN', 'AUTO_AND_VEHICLES', 'BEAUTY',
#        'BOOKS_AND_REFERENCE', 'BUSINESS', 'COMICS', 'COMMUNICATION',
#        'DATING', 'EDUCATION', 'ENTERTAINMENT', 'EVENTS', 'FINANCE',
#        'FOOD_AND_DRINK', 'HEALTH_AND_FITNESS', 'HOUSE_AND_HOME',
#        'LIBRARIES_AND_DEMO', 'LIFESTYLE', 'GAME', 'FAMILY', 'MEDICAL',
#        'SOCIAL', 'SHOPPING', 'PHOTOGRAPHY', 'SPORTS', 'TRAVEL_AND_LOCAL',
#        'TOOLS', 'PERSONALIZATION', 'PRODUCTIVITY', 'PARENTING', 'WEATHER',
#        'VIDEO_PLAYERS', 'NEWS_AND_MAGAZINES', 'MAPS_AND_NAVIGATION'],
#       dtype=object)

# %%
data['Content_Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
data['Installs'].dtype.name
# Out:
# 'float64'

# %%
data['Rating'].dtype.name
# Out:
# 'float64'

# %%
data['Size'].dtype.name
# Out:
# 'float64'

# %%
data = data.drop(['App','Last_Updated','Current_Ver'], axis = 1)

# %%
data
# Out:
#                   Category  Rating  Reviews    Size    Installs  Type  Price  \
# 0           ART_AND_DESIGN     4.1      159  19.000     10000.0  Free    0.0
# 1           ART_AND_DESIGN     3.9      967  14.000    500000.0  Free    0.0
# 2           ART_AND_DESIGN     4.7    87510   8.700   5000000.0  Free    0.0
# 3           ART_AND_DESIGN     4.5   215644  25.000  50000000.0  Free    0.0
# 4           ART_AND_DESIGN     4.3      967   2.800    100000.0  Free    0.0
# 5           ART_AND_DESIGN     4.4      167   5.600     50000.0  Free    0.0
# 6           ART_AND_DESIGN     3.8      178  19.000     50000.0  Free    0.0
# 7           ART_AND_DESIGN     4.1    36815  29.000   1000000.0  Free    0.0
# 8           ART_AND_DESIGN     4.4    13791  33.000   1000000.0  Free    0.0
# 9           ART_AND_DESIGN     4.7      121   3.100     10000.0  Free    0.0
# 10          ART_AND_DESIGN     4.4    13880  28.000   1000000.0  Free    0.0
# ...

# %%
categorical_columns = [c for c in data.columns if data[c].dtype.name == 'object']
numerical_columns   = [c for c in data.columns if data[c].dtype.name != 'object']
print(categorical_columns)
print(numerical_columns)
# Out:
# ['Category', 'Type', 'Content_Rating', 'Genres', 'Android_Ver']
# ['Rating', 'Reviews', 'Size', 'Installs', 'Price']

# %%
data.median(axis = 0)
# Out:
# Rating           4.3
# Reviews        967.0
# Size            12.0
# Installs    100000.0
# Price            0.0
# dtype: float64

# %%
data = data.fillna(data.median(axis = 0), axis = 0)

# %%
data[numerical_columns].count(axis = 0)
# Out:
# Rating      9659
# Reviews     9659
# Size        9659
# Installs    9659
# Price       9659
# dtype: int64

# %%
data[categorical_columns].count(axis = 0)
# Out:
# Category          9659
# Type              9658
# Content_Rating    9659
# Genres            9659
# Android_Ver       9657
# dtype: int64

# %%
data['Content_Rating'].describe()
# Out:
# count         9659
# unique           6
# top       Everyone
# freq          7903
# Name: Content_Rating, dtype: object

# %%
data['Content_Rating'].describe().top
# Out:
# 'Everyone'

# %%
data['Content_Rating'] = data['Content_Rating'].fillna('Everyone')

# %%
data.describe(include = [object])
# Out:
#        Category  Type Content_Rating Genres Android_Ver
# count      9659  9658           9659   9659        9657
# unique       33     2              6    118          33
# top      FAMILY  Free       Everyone  Tools  4.1 and up
# freq       1832  8902           7903    826        2202

# %%
data_describe = data.describe(include = [object])
for c in categorical_columns:
    data[c] = data[c].fillna(data_describe[c]['top'])

# %%
data.describe(include = [object])
# Out:
#        Category  Type Content_Rating Genres Android_Ver
# count      9659  9659           9659   9659        9659
# unique       33     2              6    118          33
# top      FAMILY  Free       Everyone  Tools  4.1 and up
# freq       1832  8903           7903    826        2204

# %%
#Ранее я удалил столбцы App, last_updated  и current_ver из-за большего числа уникальных элементов

# %%
binary_columns    = [c for c in categorical_columns if data_describe[c]['unique'] == 2]
nonbinary_columns = [c for c in categorical_columns if data_describe[c]['unique'] > 2]
print(binary_columns, nonbinary_columns)
# Out:
# ['Type'] ['Category', 'Content_Rating', 'Genres', 'Android_Ver']

# %%
data['Type'].unique()
# Out:
# array(['Free', 'Paid'], dtype=object)

# %%
data.at[data['Type'] == 'Free', 'Type'] = 0
data.at[data['Type'] == 'Paid', 'Type'] = 1
data['Type'].describe()
# Out:
# count    9659.000000
# mean        0.078269
# std         0.268608
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max         1.000000
# Name: Type, dtype: float64

# %%
data['Content_Rating'].unique()
# Out:
# array(['Everyone', 'Teen', 'Everyone 10+', 'Mature 17+',
#        'Adults only 18+', 'Unrated'], dtype=object)

# %%
#data.drop(['App','Last_Updated','Current_Ver'], axis = 1)

# %%
data_nonbinary = pd.get_dummies(data[nonbinary_columns])
print(data_nonbinary.columns)
# Out:
# Index(['Category_ART_AND_DESIGN', 'Category_AUTO_AND_VEHICLES',
#        'Category_BEAUTY', 'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS',
#        'Category_COMICS', 'Category_COMMUNICATION', 'Category_DATING',
#        'Category_EDUCATION', 'Category_ENTERTAINMENT',
#        ...
#        'Android_Ver_5.0 - 7.1.1', 'Android_Ver_5.0 - 8.0',
#        'Android_Ver_5.0 and up', 'Android_Ver_5.1 and up',
#        'Android_Ver_6.0 and up', 'Android_Ver_7.0 - 7.1.1',
#        'Android_Ver_7.0 and up', 'Android_Ver_7.1 and up',
#        'Android_Ver_8.0 and up', 'Android_Ver_Varies with device'],
#       dtype='object', length=190)

# %%
data_numerical = data[numerical_columns]
data_numerical.describe()
# Out:
#             Rating       Reviews         Size      Installs        Price
# count  9659.000000  9.659000e+03  9659.000000  9.659000e+03  9659.000000
# mean      4.192442  2.165926e+05    19.328821  7.777507e+06     1.099299
# std       0.496397  1.831320e+06    20.584676  5.375828e+07    16.852152
# min       1.000000  0.000000e+00     0.008500  0.000000e+00     0.000000
# 25%       4.000000  2.500000e+01     5.300000  1.000000e+03     0.000000
# 50%       4.300000  9.670000e+02    12.000000  1.000000e+05     0.000000
# 75%       4.500000  2.940100e+04    25.000000  1.000000e+06     0.000000
# max       5.000000  7.815831e+07   100.000000  1.000000e+09   400.000000

# %%
data_numerical = (data_numerical - data_numerical.mean(axis = 0))/data_numerical.std(axis = 0)

# %%
data_numerical.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price
# count  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03
# mean  -1.290969e-13 -1.812561e-16  5.170289e-15 -1.300256e-15 -2.643374e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.431227e+00 -1.182713e-01 -9.385778e-01 -1.446755e-01 -6.523197e-02
# 25%   -3.876781e-01 -1.182577e-01 -6.815177e-01 -1.446569e-01 -6.523197e-02
# 50%    2.166768e-01 -1.177433e-01 -3.560328e-01 -1.428153e-01 -6.523197e-02
# 75%    6.195800e-01 -1.022168e-01  2.755049e-01 -1.260737e-01 -6.523197e-02
# max    1.626838e+00  4.256041e+01  3.918992e+00  1.845711e+01  2.367061e+01

# %%
data = pd.concat((data_numerical, data_nonbinary, data[binary_columns]), axis = 1)
print(data.shape)
# Out:
# (9659, 196)

# %%
data.describe()
# Out:
#              Rating       Reviews          Size      Installs         Price  \
# count  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03  9.659000e+03
# mean  -1.290969e-13 -1.812561e-16  5.170289e-15 -1.300256e-15 -2.643374e-17
# std    1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00  1.000000e+00
# min   -6.431227e+00 -1.182713e-01 -9.385778e-01 -1.446755e-01 -6.523197e-02
# 25%   -3.876781e-01 -1.182577e-01 -6.815177e-01 -1.446569e-01 -6.523197e-02
# 50%    2.166768e-01 -1.177433e-01 -3.560328e-01 -1.428153e-01 -6.523197e-02
# 75%    6.195800e-01 -1.022168e-01  2.755049e-01 -1.260737e-01 -6.523197e-02
# max    1.626838e+00  4.256041e+01  3.918992e+00  1.845711e+01  2.367061e+01
#
#        Category_ART_AND_DESIGN  Category_AUTO_AND_VEHICLES  Category_BEAUTY  \
# count              9659.000000                   9659.0000      9659.000000
# mean                  0.006626                      0.0088         0.005487
# ...

# %%
X = data.drop(('Type'), axis = 1) 
y = data['Type']
feature_names = X.columns

# %%
type(feature_names)
# Out:
# pandas.core.indexes.base.Index

# %%
feature_names
# Out:
# Index(['Rating', 'Reviews', 'Size', 'Installs', 'Price',
#        'Category_ART_AND_DESIGN', 'Category_AUTO_AND_VEHICLES',
#        'Category_BEAUTY', 'Category_BOOKS_AND_REFERENCE', 'Category_BUSINESS',
#        ...
#        'Android_Ver_5.0 - 7.1.1', 'Android_Ver_5.0 - 8.0',
#        'Android_Ver_5.0 and up', 'Android_Ver_5.1 and up',
#        'Android_Ver_6.0 and up', 'Android_Ver_7.0 - 7.1.1',
#        'Android_Ver_7.0 and up', 'Android_Ver_7.1 and up',
#        'Android_Ver_8.0 and up', 'Android_Ver_Varies with device'],
#       dtype='object', length=195)

# %%
print(X.shape)
print(y.shape)
N, d = X.shape
# Out:
# (9659, 195)
# (9659,)

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

N_train, _ = X_train.shape 
N_test,  _ = X_test.shape 

print(N_train, N_test)
# Out:
# 6761 2898

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors = 10)
#knn.set_params(n_neighbors=10)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
knn
# Out:
# KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#                      metric_params=None, n_jobs=None, n_neighbors=10, p=2,
#                      weights='uniform')

# %%
y_train_predict = knn.predict(X_train)
y_test_predict = knn.predict(X_test)

err_train = np.mean(y_train != y_train_predict)
err_test  = np.mean(y_test  != y_test_predict)

print(err_train, err_test)
# Out:
# 0.0696642508504659 0.07142857142857142

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, y_test_predict))
# Out:
# [[2676    1]
#  [ 206   15]]

# %%
confusion_matrix([0,1,0,1,0], [0,1,0,0,0])
# Out:
# array([[3, 0],
#        [1, 1]], dtype=int64)

# %%
from sklearn.model_selection import GridSearchCV
nnb = [1, 3, 5, 10, 15, 20, 25, 35, 45, 55]
knn = KNeighborsClassifier()
grid = GridSearchCV(knn, param_grid = {'n_neighbors': nnb}, cv=10)
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_n_neighbors = grid.best_estimator_.n_neighbors
print(best_cv_err, best_n_neighbors)
# Out:
# 0.06892471527880495 5

# %%
knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.05886703150421535 0.06694271911663216

# %%
from sklearn.svm import SVC
svc = SVC()
svc.fit(X_train, y_train)

err_train = np.mean(y_train != svc.predict(X_train))
err_test  = np.mean(y_test  != svc.predict(X_test))

print(err_train, err_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.0724744860227777 0.07039337474120083

# %%
from sklearn.model_selection import learning_curve,GridSearchCV
Cs = 10.**np.arange(-5, 5)
gamma_array = 10.**np.arange(-5, 5)
svc = SVC()
grid = GridSearchCV(svc, param_grid = {'C': Cs, 'gamma': gamma_array})
grid.fit(X_train, y_train)

best_cv_err = 1 - grid.best_score_
best_C = grid.best_estimator_.C
print(best_cv_err, best_C)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py:1978: FutureWarning: The default value of cv will change from 3 to 5 in version 0.22. Specify it explicitly to silence this warning.
#   warnings.warn(CV_WARNING, FutureWarning)
# 0.0 1000.0

# %%
svc = SVC(C = best_C).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# D:\Anaconda3\lib\site-packages\sklearn\svm\base.py:193: FutureWarning: The default value of gamma will change from 'auto' to 'scale' in version 0.22 to account better for unscaled features. Set gamma explicitly to 'auto' or 'scale' to avoid this warning.
#   "avoid this warning.", FutureWarning)
# 0.05886703150421535 0.06694271911663216

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0

# %%
a=[1,2,5,70,32,3,4,7,234, 3]
a[-1:3:-1]
# Out:
# [3, 234, 7, 4, 3, 32]

# %%
np.sum(rf.feature_importances_)
# Out:
# 1.0000000000000002

# %%
importances = rf.feature_importances_
indices = np.argsort(importances)[::-1]

print("Feature ranking:")

for f in range(d):
    print("%2d. feature '%5s' (%f)" % (f + 1, feature_names[indices[f]], importances[indices[f]]))
# Out:
# Feature ranking:
#  1. feature 'Price' (0.722216)
#  2. feature 'Reviews' (0.045745)
#  3. feature 'Installs' (0.044489)
#  4. feature ' Size' (0.033841)
#  5. feature 'Rating' (0.022572)
#  6. feature 'Android_Ver_1.6 and up' (0.004962)
#  7. feature 'Genres_Education;Pretend Play' (0.004619)
#  8. feature 'Category_PERSONALIZATION' (0.004534)
#  9. feature 'Genres_Personalization' (0.004276)
# 10. feature 'Android_Ver_Varies with device' (0.004238)
# 11. feature 'Genres_Board;Brain Games' (0.003460)
# 12. feature 'Genres_Medical' (0.003386)
# 13. feature 'Android_Ver_4.0 and up' (0.003384)
# 14. feature 'Category_MEDICAL' (0.003309)
# 15. feature 'Content_Rating_Everyone' (0.003207)
# 16. feature 'Android_Ver_4.1 and up' (0.003206)
# 17. feature 'Android_Ver_2.3 and up' (0.003150)
# 18. feature 'Android_Ver_7.0 and up' (0.003025)
# 19. feature 'Android_Ver_4.0.3 and up' (0.002802)
# 20. feature 'Genres_Role Playing' (0.002583)
# 21. feature 'Android_Ver_2.1 and up' (0.002350)
# ...

# %%
feature_names[[1,0,1]]
# Out:
# Index(['Reviews', 'Rating', 'Reviews'], dtype='object')

# %%
d_first = 20
plt.title("Feature importances")
plt.bar(range(d_first), importances[indices[:d_first]], align = 'center', color = 'r')
plt.xticks(range(d_first), feature_names[indices[:d_first]], rotation = 90)
plt.xlim([-1, d_first])
# Out:
# (-1, 20)

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.03036576949620428

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.0

# %%
# После этапа векторизации размер моей базы составил (9659, 14049). Я пытался удалить столбцы с наибольшим количеством 
# уникальных элементов, но они всё-равно остаются в базе. Думаю проблема этом. Все данные приведены к нужному типу, 
# ошибка возникает во время обучения.
# upd: столбцы удалились - я не обновлял базу данных. Y сделал бинарным (был float с ошибкой). После kNN и SVC долго считает.

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

# %%
principalDf
# Out:
#       principal component 1  principal component 2
# 0                 -0.216691               0.070791
# 1                 -0.278688               0.453768
# 2                 -0.055857              -0.124723
# 3                  0.678182              -0.513021
# 4                 -0.263673               0.477585
# 5                 -0.231604               0.287279
# 6                 -0.277113               0.367012
# 7                 -0.129756              -0.275927
# 8                 -0.054881              -0.714595
# 9                 -0.185149               0.065144
# 10                -0.080229              -0.594517
# 11                -0.182655               0.071719
# 12                 0.009795              -0.199813
# 13                -0.097974              -0.489866
# 14                -0.051059              -0.871459
# 15                -0.489717               1.578952
# 16                -0.158192              -0.061924
# ...

# %%
finalDf = pd.concat([principalDf, y], axis = 1)

# %%
finalDf
# Out:
#        principal component 1  principal component 2  Type
# 0                  -0.216691               0.070791   0.0
# 1                  -0.278688               0.453768   0.0
# 2                  -0.055857              -0.124723   0.0
# 3                   0.678182              -0.513021   0.0
# 4                  -0.263673               0.477585   0.0
# 5                  -0.231604               0.287279   0.0
# 6                  -0.277113               0.367012   0.0
# 7                  -0.129756              -0.275927   0.0
# 8                  -0.054881              -0.714595   0.0
# 9                  -0.185149               0.065144   0.0
# 10                 -0.080229              -0.594517   0.0
# 11                 -0.182655               0.071719   0.0
# 12                  0.009795              -0.199813   0.0
# 13                 -0.097974              -0.489866   0.0
# 14                 -0.051059              -0.871459   0.0
# ...

# %%
print(y.shape)
# Out:
# (9659,)

# %%
fig = plt.figure(figsize = (8,8))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 component PCA', fontsize = 20)

targets = [0, 1]
colors = ['g', 'r']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Type'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 50)
ax.legend(targets)
ax.grid()

# %%
X_train, X_test, y_train, y_test = train_test_split(principalDf, y, test_size = 0.3, random_state = 42)

knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train = np.mean(y_train != knn.predict(X_train))
err_test  = np.mean(y_test  != knn.predict(X_test))

print(err_train, err_test)
# Out:
# 0.07439727850909629 0.07832988267770877

# %%
pca = PCA(n_components=3)
principalComponents = pca.fit_transform(X)
principalDf3 = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 
                                                                  'principal component 3'])

# %%
X_train, X_test, y_train, y_test = train_test_split(principalDf3, y, test_size = 0.3, random_state = 42)

knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train3 = np.mean(y_train != knn.predict(X_train))
err_test3  = np.mean(y_test  != knn.predict(X_test))

print(err_train3, err_test3)
# Out:
# 0.06685401567815412 0.07867494824016563

# %%
pca = PCA(n_components=4)
principalComponents = pca.fit_transform(X)
principalDf4 = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 
                                                                  'principal component 3', 'principal component 4'])

# %%
X_train, X_test, y_train, y_test = train_test_split(principalDf4, y, test_size = 0.3, random_state = 42)

knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train4 = np.mean(y_train != knn.predict(X_train))
err_test4  = np.mean(y_test  != knn.predict(X_test))

print(err_train4, err_test4)
# Out:
# 0.025440023665138294 0.03692201518288475

# %%
pca = PCA(n_components=5)
principalComponents = pca.fit_transform(X)
principalDf5 = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 
                                                                  'principal component 3', 'principal component 4',
                                                                   'principal component 5'])

# %%
X_train, X_test, y_train, y_test = train_test_split(principalDf5, y, test_size = 0.3, random_state = 42)

knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train5 = np.mean(y_train != knn.predict(X_train))
err_test5  = np.mean(y_test  != knn.predict(X_test))

print(err_train5, err_test5)
# Out:
# 0.025735837893802693 0.03761214630779848

# %%
pca = PCA(n_components=6)
principalComponents = pca.fit_transform(X)
principalDf6 = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2', 
                                                                  'principal component 3', 'principal component 4',
                                                                   'principal component 5', 'principal component 6'])

# %%
X_train, X_test, y_train, y_test = train_test_split(principalDf6, y, test_size = 0.3, random_state = 42)

knn = KNeighborsClassifier(n_neighbors = best_n_neighbors).fit(X_train, y_train)

err_train6 = np.mean(y_train != knn.predict(X_train))
err_test6  = np.mean(y_test  != knn.predict(X_test))

print(err_train6, err_test6)
# Out:
# 0.034462357639402454 0.044513457556935816

# %%
Ox = [2,3,4,5,6]
Oy1 = [err_train, err_train3, err_train4, err_train5, err_train6]
Oy2 = [err_test, err_test3, err_test4, err_test5, err_test6]
plt.figure(figsize = (12, 8))
plt.xticks(range(2,7))
plt.xlabel('Кол-во главных компонент')
plt.ylabel('Ошибка')
plt.plot(Ox, Oy1)
plt.plot(Ox, Oy2)
plt.grid(True)
plt.show()

# %% [markdown]
# Снизу ошибка на тренировочных данных, сверху - на тестовых

# %% [markdown]
# Наилучшее кол-во ближайших соседей 5. При количестве главных компонент 4 ошибка минимальна. Далее при увеличении кол-ва компонент растёт ошибка.

# %%
print(N_train, N_test)
# Out:
# 6761 2898

# %%
from sklearn.neural_network import MLPClassifier

# %%
mlp_model = MLPClassifier(hidden_layer_sizes = (100,), solver = 'lbfgs', 
                          activation = 'logistic', random_state = 42)
mlp_model.fit(X_train, y_train)
# Out:
# MLPClassifier(activation='logistic', alpha=0.0001, batch_size='auto',
#               beta_1=0.9, beta_2=0.999, early_stopping=False, epsilon=1e-08,
#               hidden_layer_sizes=(100,), learning_rate='constant',
#               learning_rate_init=0.001, max_iter=200, momentum=0.9,
#               n_iter_no_change=10, nesterovs_momentum=True, power_t=0.5,
#               random_state=42, shuffle=True, solver='lbfgs', tol=0.0001,
#               validation_fraction=0.1, verbose=False, warm_start=False)

# %%
y_train_pred = mlp_model.predict(X_train)
y_test_pred = mlp_model.predict(X_test)

# %% [markdown]
# Ошибки на обучающей и тестовой выборках:

# %%
print(np.mean(y_train != y_train_pred), np.mean(y_test != y_test_pred))
# Out:
# 0.07913030616772666 0.07625948930296757

# %% [markdown]
# ## Подбор гиперпараметров

# %%
alpha_arr = np.logspace(-3, 2, 21)
test_err = []
train_err = []
for alpha in alpha_arr:
    mlp_model = MLPClassifier(alpha = alpha, hidden_layer_sizes = (100,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(alpha_arr, train_err, 'r-o', label = 'train')
plt.semilogx(alpha_arr, test_err, 'b-o', label = 'test')
plt.xlim([np.max(alpha_arr), np.min(alpha_arr)])
plt.title('Error vs. alpha')
plt.xlabel('alpha')
plt.ylabel('error')
plt.legend()
pass

# %% [markdown]
# Минимальное значение ошибки:

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0003450655624568668

# %% [markdown]
# Оптимальное значение alpha:

# %%
alpha_opt = alpha_arr[test_err == min_test_err]
print(alpha_opt)
# Out:
# [0.00177828 0.00316228 0.00562341 0.01       0.01778279 0.03162278
#  0.05623413]

# %%
alpha_opt = alpha_opt[0]

# %%
layer_sizes_arr = (10, 100, 500, 1000)
test_err = []
train_err = []
for size in layer_sizes_arr:
    mlp_model = MLPClassifier(alpha = alpha_opt, hidden_layer_sizes = (size,), 
                              solver = 'lbfgs', activation = 'logistic', random_state = 42)
    mlp_model.fit(X_train, y_train)

    y_train_pred = mlp_model.predict(X_train)
    y_test_pred = mlp_model.predict(X_test)
    train_err.append(np.mean(y_train != y_train_pred))
    test_err.append(np.mean(y_test != y_test_pred))

# %%
plt.semilogx(layer_sizes_arr, train_err, 'b-o', label = 'train')
plt.semilogx(layer_sizes_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(layer_sizes_arr), np.min(layer_sizes_arr)])
plt.title('Error vs. layer_size')
plt.xlabel('layer_size')
plt.ylabel('error')
plt.legend()
pass

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.0

# %%
size_opt = layer_sizes_arr[test_err == min_test_err]
print(size_opt)
# Out:
# [ 2  4  5  8 10 16 33 38 44 57 66 74 83]

# %% [markdown]
# ## Random Forest

# %%
from sklearn import ensemble
rf = ensemble.RandomForestClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.039337474120082816

# %%
trees_arr = np.arange(25, 100, 5)
test_err = []
train_err = []
oob_err = []
for trees in trees_arr:
    rf = ensemble.RandomForestClassifier(n_estimators = trees, oob_score=True)
    rf.fit(X_train, y_train)
    train_err.append(np.mean(y_train != rf.predict(X_train)))
    test_err.append(np.mean(y_test  != rf.predict(X_test)))
    oob_err.append(1 - rf.oob_score_)

# %%
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.plot(trees_arr, oob_err, 'g-o', label = 'oob')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. trees Random forest')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()

# %% [markdown]
# Наблюдается переобучение

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.038302277432712216

# %% [markdown]
# ## Gradient Boosted Trees

# %%
from sklearn import ensemble
rf = ensemble.GradientBoostingClassifier(n_estimators = 1000)
rf.fit(X_train, y_train)

err_train = np.mean(y_train != rf.predict(X_train))
err_test  = np.mean(y_test  != rf.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.03243616287094548

# %%
trees_arr = np.arange(50, 1000, 50)
test_err = []
train_err = []
for trees in trees_arr:
    gbt = ensemble.GradientBoostingClassifier(n_estimators = trees)
    gbt.fit(X_train, y_train)
    train_err.append(np.mean(y_train != gbt.predict(X_train)))
    test_err.append(np.mean(y_test  != gbt.predict(X_test)))

# %%
plt.plot(trees_arr, train_err, 'b-o', label = 'train')
plt.plot(trees_arr, test_err, 'r-o', label = 'test')
plt.xlim([np.max(trees_arr), np.min(trees_arr)])
plt.title('Error vs. trees GBT')
plt.xlabel('trees')
plt.ylabel('error')
plt.legend()

# %%
min_train_err = np.min(train_err)
min_test_err = np.min(test_err)
print(min_train_err, min_test_err)
# Out:
# 0.0 0.033126293995859216

# %% [markdown]
# ## AdaBoost

# %%
ada = ensemble.AdaBoostClassifier(n_estimators = 1000)
ada.fit(X_train, y_train)

err_train = np.mean(y_train != ada.predict(X_train))
err_test = np.mean(y_test != ada.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0014790711433219938 0.022429261559696344

# %% [markdown]
# ## GBT

# %%
gbt = ensemble.GradientBoostingClassifier(n_estimators = 1000)
gbt.fit(X_train, y_train)

err_train = np.mean(y_train != gbt.predict(X_train))
err_test = np.mean(y_test != gbt.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.03243616287094548

# %% [markdown]
# ## Extremely Randomized Trees

# %%
ert = ensemble.ExtraTreesClassifier(n_estimators = 100).fit(X_train, y_train)

err_train = np.mean(y_train != ert.predict(X_train))
err_test  = np.mean(y_test  != ert.predict(X_test))

print(err_train, err_test)
# Out:
# 0.0 0.038302277432712216

# %% [markdown]
# Наименьшую ошибку удалось достичь, применяя метод AdaBoost.
